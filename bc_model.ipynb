# %%
# !pip install openseespy opsvis  #required in colab, not required in local environment
import matplotlib.pyplot as plt
import numpy as np
import openseespy.opensees as ops
import opsvis

# %%
# unit 1 of park (Model 1)
mm = 1
kN  = 1
N = kN/1000
m = 1000*mm
MPa = N/mm**2
###

# %%
DBeam = 457*mm #key
DCol = 406*mm   #key

# %%
ops.wipe()
ops.model("Basic","-ndm",2,"-ndf",3)  #model is 2d with three degrees of freedom per node

beamPlasticHingeLength = DBeam/2  #originally divide by 2
# beamPlasticHingeLength = DBeam #originally divide by 2
columnPlasticHingeLength = DCol/2  #originally divide by 2

# %%
# Nodes definition
#left beam
#2-200 plastic hinge->heavy section discretization
ops.node(1,0,0)     #center node of the subassembles
ops.node(2,-DCol/4,0)  #left end of the rigid link
ops.node(200, -DCol/4 - beamPlasticHingeLength,0) #end of plastic hinge
ops.node(3,-848*mm,0)  #left end of the beam where gravity load is applied
ops.node(4,-2119*mm,0)  #extreme left end

#right beam
#500-5 plastic hinge->heavy section discretization
ops.node(5,DCol/4,0*mm)  #right rigid link
ops.node(500, +DCol/4 + beamPlasticHingeLength,0) #end of plastic hinge
ops.node(6,848*mm,0*mm)  #right beam where gravity load is applied
ops.node(7,2119*mm,0*mm)  #right extreme beam



#top column 8-800 rigid link
ops.node(8,0,DBeam/4*mm) #column top rigid link
ops.node(800,0,DBeam/4*mm + columnPlasticHingeLength) #column top rigid link
ops.node(9,0,1236*mm) #column top extreme->lateral displacement node

#bottom column
ops.node(10,0,-DBeam/4) #column bottom rigid link
ops.node(1000,0,-DBeam/4-columnPlasticHingeLength) #end of plastic hinge
ops.node(11,0,-1236*mm) #column bottom extreme

# %%
# ########################## Here we define the nodes for the columns ##############################
# 1236 is the distance of the extreme end of the column from the beam column joint center
differenceColumn = -DBeam/4-DCol/2 + 1236  #length of the column excluding plastic hinge length and rigid link lengths
numEleCol = 2
lengthEleCol = differenceColumn/numEleCol

[ops.node(51+i, 0, -DBeam/4 - columnPlasticHingeLength - i*lengthEleCol) for i in range(1,numEleCol)]   #for the bottom column

[ops.node(501+i, 0, +DBeam/4 + columnPlasticHingeLength + i*lengthEleCol) for i in range(1,numEleCol)] #for the top column
# Out:
# [None]

# %%
# ########################## Here we define the nodes for the beams ##############################
# lengthof the beam on eigher side is 2119 mm from the joint center
differenceBeam1 = -DCol/4 - DBeam/2 + 848 #this is the length of the beam upto the gravity loading point excluding pH length on either side
differenceBeam2 = -848 + 2119 #This is the length of the beam from the gravity load point to the extreme end

numEleBeam1 = 2
numEleBeam2 = 2
lengthEleBeam1 = differenceBeam1/numEleBeam1
lengthEleBeam2 = differenceBeam2/numEleBeam2  #These were used previously to discretize the beam when all the elements were modeled with distributed plasticity
# lengthEleBeam1 is for the elements right next to the plastic hinge zone
# lengthEleBeam3 is for the elements right next to the  nodes with gravity loads


#for the beam to the left of the joint
[ops.node(5001+i, -DCol/4 - beamPlasticHingeLength - i*lengthEleBeam1, 0) for i in range(1,numEleBeam1)]  
[ops.node(5051+i, -848 - i*lengthEleBeam2, 0) for i in range(1,numEleBeam2)]


#for the beam to the right of the joint
[ops.node(6001+i, +DCol/4 + beamPlasticHingeLength + i*lengthEleBeam1, 0) for i in range(1,numEleBeam1)]  
[ops.node(6051+i, +848 + i*lengthEleBeam2, 0) for i in range(1,numEleBeam2)]
# Out:
# [None]

# %%
#here we give section definitions using fiber sections, could have used RCSection2d as well!!
#two different sections have been defined for each columns and beams
#one heavily discretized section for plastic hinge regions and one lightly discretized section for the rest of the member length
# 1->plastic hinge section for beam
# 2->sections other than plastic hinge section for beam
# 3->plastic hinge section for column
# 1->sections other than plastic hinge section for column
transfTag = 1
ops.geomTransf("Linear",transfTag)
# ops.rigidLink("-beam",1,2)
# ops.rigidLink("-beam",1,8)
# ops.rigidLink("-beam",1,5)
# ops.rigidLink("-beam",1,10)
fck = 39.1
Econc = 5000*np.sqrt(fck) *MPa  #as per IS 456:2000 code
# I_rig  = 1e10
# A_rig = 1e10
# ops.element("elasticBeamColumn",100,1,2,A_rig,E_rig,I_rig,transfTag)
# ops.element("elasticBeamColumn",101,1,8,A_rig,E_rig,I_rig,transfTag)
# ops.element("elasticBeamColumn",102,1,5,A_rig,E_rig,I_rig,transfTag)
# ops.element("elasticBeamColumn",103,1,10,A_rig,E_rig,I_rig,transfTag)



secTagBeamAtPlasticHinges = 1
secTagBeam = 2
secTagColumnAtPlasticHinges = 3
secTagColumn = 4

# %%
# ################################### For beam:  ##########################
#defining these parameters so that elements outside of the plastic hinge length can be modeled as elastic beam column elements
#These are to be changed while defining sections, hence key parameters for the research work
Bbeam = 229*mm  #key
Hbeam = 457*mm  #key

#may be i would benefit from using the elastic section for the elastic beam column elements
#  as i have already defined the fiber section layout here
Ibeam = 0.35 * Bbeam*Hbeam**3/12
Abeam = Bbeam*Hbeam
c = 42*mm  # cover  #consistent

y1col = Hbeam/2.0
z1col = Bbeam/2.0
separation_between_bars = 33*mm
y2col = y1col - c - separation_between_bars

nFibZCoverTopBottom = 3
nFibZCoverLeftRight = 2
nFibZCore = 7
nFib = 7
nFibCover, nFibCore = 2, 20
As9 = np.pi*16**2/4  #6 #9 bars for compression and tension face  #key
Fy = 294 * N/mm**2  #done   #key



# uniaxialMaterial('Concrete02', matTag, fpc, epsc0, fpcu, epsU, lambda, ft, Ets)
# ops.uniaxialMaterial("Concrete02", 2, -39*MPa, -0.002,-0.2*39*MPa,-0.004,0.3,2*MPa,3.6e3)  #unconfined concrete
ops.uniaxialMaterial("Concrete02", 2, -39*MPa, -0.002,0*MPa,-0.004,0.3,2*MPa,3.6e3)  #unconfined concrete

# ops.uniaxialMaterial("Concrete02", 3, -48*MPa, -0.003,-0.2*48*MPa,-0.01,0.3,2*MPa,3.6e3)   #confined concrete
ops.uniaxialMaterial("Concrete02", 3, -48*MPa, -0.003,0*MPa,-0.01,0.3,2*MPa,3.6e3)   #confined concrete

# uniaxialMaterial('Steel02', matTag, Fy, E0, b, *params, a1=a2*Fy/E0, a2=1.0, a3=a4*Fy/E0, a4=1.0, sigInit=0.0)
# R0=between 10 and 20, cR1=0.925, cR2=0.15
# D16 Rebar - Beam
# uniaxialMaterial     Steel02     2002     295000000.00000     210000000000.00000     0.00400     20.00000     0.92500     0.15000
fyBeamRebar = 295*MPa
# EBeamRebar =  0.35*210e3*MPa
EBeamRebar =  210e3*MPa
ops.uniaxialMaterial('Steel02', 4, fyBeamRebar,EBeamRebar , 0.004, 20,0.925,0.15) #material for rebar
# ops.uniaxialMaterial("Steel02",3,2500)  #material for unconfined concrete
# ops.uniaxialMaterial("Elastic",3,2500)  #material for confined concrete
# ops.uniaxialMaterial("Elastic",4,2500)   #material for rebar


beamSectionAtPlasticHinges = [['section', 'Fiber', secTagBeamAtPlasticHinges, '-GJ', 1.0e6],
             ['patch', 'rect', 3, nFibCore, nFibZCore, c-y1col, c-z1col, y1col-c, z1col-c],
             ['patch', 'rect', 2, nFib, nFibZCoverLeftRight, -y1col, -z1col, y1col, c-z1col],
             ['patch', 'rect', 2, nFib, nFibZCoverLeftRight, -y1col, z1col-c, y1col, z1col],
             ['patch', 'rect', 2, nFibCover, nFibZCoverTopBottom, -y1col, c-z1col, c-y1col, z1col-c],
             ['patch', 'rect', 2, nFibCover, nFibZCoverTopBottom, y1col-c, c-z1col, y1col, z1col-c],
             ['layer', 'straight', 4, 3, As9, y1col-c, z1col-c, y1col-c, c-z1col],
             ['layer', 'straight', 4, 2, As9, y2col, z1col-c, y2col, c-z1col],
             ['layer', 'straight', 4, 2, As9, c-y1col, z1col-c, c-y1col, c-z1col]]


opsvis.fib_sec_list_to_cmds(beamSectionAtPlasticHinges)

nFibZCoverTopBottom = 3
nFibZCoverLeftRight = 2
nFibZCore = 5
nFib = 5
nFibCover, nFibCore = 2, 4

beamSection = [['section', 'Fiber', secTagBeam, '-GJ', 1.0e6],
             ['patch', 'rect', 2, nFibCore, nFibZCore, c-y1col, c-z1col, y1col-c, z1col-c],
             ['patch', 'rect', 2, nFib, nFibZCoverLeftRight, -y1col, -z1col, y1col, c-z1col],
             ['patch', 'rect', 2, nFib, nFibZCoverLeftRight, -y1col, z1col-c, y1col, z1col],
             ['patch', 'rect', 2, nFibCover, nFibZCoverTopBottom, -y1col, c-z1col, c-y1col, z1col-c],
             ['patch', 'rect', 2, nFibCover, nFibZCoverTopBottom, y1col-c, c-z1col, y1col, z1col-c],
             ['layer', 'straight', 4, 3, As9, y1col-c, z1col-c, y1col-c, c-z1col],
             ['layer', 'straight', 4, 2, As9, y2col, z1col-c, y2col, c-z1col],
             ['layer', 'straight', 4, 2, As9, c-y1col, z1col-c, c-y1col, c-z1col]]


opsvis.fib_sec_list_to_cmds(beamSection)

matcolor = ['r', 'lightgrey', 'gold', 'w', 'w', 'w']
opsvis.plot_fiber_section(beamSectionAtPlasticHinges, matcolor=matcolor)
plt.axis('equal')


# matcolor = ['r', 'lightgrey', 'gold', 'w', 'w', 'w']
# opsvis.plot_fiber_section(beamSection, matcolor=matcolor)
# plt.axis('equal')
# plt.show()
# Out:
# (np.float64(125.95),
#  np.float64(-125.95),
#  np.float64(-251.35),
#  np.float64(251.35))

# %%
# ############################################## For column: #######################################

#defining these parameters so that elements outside of the plastic hinge length can be modeled as elastic beam column elements
Bcol = 305*mm
Hcol = 406*mm
Icol = 0.7 * Bbeam*Hbeam**3/12
Acol = Bcol*Hcol


# L_RL_beam = Hcol/4
# L_RL_col = Hbeam/4

c = 43*mm  # cover

y1col = Hcol/2.0
z1col = Bcol/2.0

fyColumnRebar = 500*MPa
# fyColumnRebar = 295*MPa
# EColumnRebar = 0.7*210e3*MPa
EColumnRebar = 200e3*MPa

# nFibZ = 1  #do separate discretization for the core and the cover later
# nFib = 20
nFibCover,nFibCover2, nFibCore = 4,2, 16
nFibZCoverTopBottom = 3
nFibZCoverLeftRight = 2
nFibZCore = 7
nFib = 7
nFibCover, nFibCore = 2, 20
# As9 = 1*mm*mm  #four #9 bars cover is 2.5 mmes
# uniaxialMaterial('Concrete02', matTag, fpc, epsc0, fpcu, epsU, lambda, ft, Ets)
ops.uniaxialMaterial("Concrete02", 5, -39*MPa, -0.002,-0.2*39*MPa,-0.004,0.3,2*MPa,3.6e3)  #unconfined concrete
ops.uniaxialMaterial("Concrete02", 6, -48*MPa, -0.003,-0.2*48*MPa,-0.01,0.3,2*MPa,3.6e3)  #confined concrete
# # ops.uniaxialMaterial("Elastic",6,2500)  #material for unconfined concrete
# # ops.uniaxialMaterial("Elastic",7,2500)   #material for rebar
# # ops.uniaxialMaterial('Steel02', 7, fyColumnRebar, EColumnRebar, 0.004, 20,0.925,0.15)
ops.uniaxialMaterial('Steel02', 7, fyColumnRebar, EColumnRebar, 0.004, 20,0.925,0.15) #material for rebar




columnSectionAtPlasticHinges = [['section', 'Fiber', secTagColumnAtPlasticHinges, '-GJ', 1.0e6],
             ['patch', 'rect', 6, nFibCore, nFibCore, c-y1col, c-z1col, y1col-c, z1col-c],
             ['patch', 'rect', 5, nFibCover, nFibZCoverLeftRight, -y1col, -z1col, y1col, c-z1col],
             ['patch', 'rect', 5, nFibCover, nFibZCoverLeftRight, -y1col, z1col-c, y1col, z1col],
             ['patch', 'rect', 5, nFibCover2, nFibZCoverTopBottom, -y1col, c-z1col, c-y1col, z1col-c],
             ['patch', 'rect', 5, nFibCover2, nFibZCoverTopBottom, y1col-c, c-z1col, y1col, z1col-c],
             ['layer', 'straight', 7, 3, As9, y1col-c, z1col-c, y1col-c, c-z1col],
             ['layer', 'straight', 7, 2, As9, 0, z1col-c, 0, c-z1col],
             ['layer', 'straight', 7, 3, As9, c-y1col, z1col-c, c-y1col, c-z1col]]


opsvis.fib_sec_list_to_cmds(columnSectionAtPlasticHinges)

#column section at places other than plastic hinges
nFibCover,nFibCover2, nFibCore = 4,2, 8 #at sections other than plastic hinges
columnSection = [['section', 'Fiber', secTagColumn, '-GJ', 1.0e6],
             ['patch', 'rect', 5, nFibCore, nFibCore, c-y1col, c-z1col, y1col-c, z1col-c],
             ['patch', 'rect', 5, nFibCover, nFibZCoverLeftRight, -y1col, -z1col, y1col, c-z1col],
             ['patch', 'rect', 5, nFibCover, nFibZCoverLeftRight, -y1col, z1col-c, y1col, z1col],
             ['patch', 'rect', 5, nFibCover2, nFibZCoverTopBottom, -y1col, c-z1col, c-y1col, z1col-c],
             ['patch', 'rect', 5, nFibCover2, nFibZCoverTopBottom, y1col-c, c-z1col, y1col, z1col-c],
             ['layer', 'straight', 7, 3, As9, y1col-c, z1col-c, y1col-c, c-z1col],
             ['layer', 'straight', 7, 2, As9, 0, z1col-c, 0, c-z1col],
             ['layer', 'straight', 7, 3, As9, c-y1col, z1col-c, c-y1col, c-z1col]]


opsvis.fib_sec_list_to_cmds(columnSection)


# matcolor = ['r', 'lightgrey', 'gold', 'w', 'w', 'w']
# opsvis.plot_fiber_section(columnSectionAtPlasticHinges, matcolor=matcolor)
# plt.axis('equal')

# matcolor = ['r', 'lightgrey', 'gold', 'w', 'w', 'w']
# opsvis.plot_fiber_section(columnSection, matcolor=matcolor)
# plt.axis('equal')

# matcolor = ['r', 'lightgrey', 'gold', 'w', 'lightgrey', 'gold','w']
# opsvis.plot_fiber_section(columnSection, matcolor=matcolor)
# plt.axis('equal')

# # element('elasticBeamColumn', eleTag, *eleNodes, secTag, transfTag, <'-mass', mass>, <'-cMass'>, <'-release', releaseCode>)
# # ops.element("elasticBeamColumn",1,1,2,secTagColumn,transfTag)
# # ops.element("elasticBeamColumn",2,2,3,secTagColumn,transfTag)
# # ops.element("elasticBeamColumn",3,2,4,secTagBeam,transfTag)

# %%
# here we define the beam integration rules for the different elements
# by default integration points are set to be 5 for each element
#could be taken higher for elements in the plastic hinge regions
integrationTagBeamPlasticHinges = 1
integrationTagBeam = 2

integrationTagColumn = 3
integrationTagColumnPlasticHinges = 4

# # beamIntegration('Lobatto', tag, secTag, N)
ops.beamIntegration("Lobatto",integrationTagBeamPlasticHinges, secTagBeamAtPlasticHinges, 5)
ops.beamIntegration("Lobatto",integrationTagBeam, secTagBeam, 5)

ops.beamIntegration("Lobatto",integrationTagColumnPlasticHinges,secTagColumnAtPlasticHinges, 5)
ops.beamIntegration("Lobatto",integrationTagColumn,secTagColumn, 5)

# %%
#################### left beam of the plastic hinge region#############
# # ops.element('forceBeamColumn', eleTag, *eleNodes, transfTag, integrationTag, '-iter', maxIter=10, tol=1e-12, '-mass', mass=0.0)
ops.element("dispBeamColumn", 1, *[200,2], transfTag, integrationTagBeamPlasticHinges) #left beam plastic hinge region

# first beam to the left of the plastic hinge region for the left beam which is to be omitted for an external joint
# this lump of code you see is because the first and last elements connect different nodes that don't fit into a pattern and 
# the middle ones connect the consecutive nodes, for example, for first beam on the left outside of the ph connects node 200 to node 5002
# and the last connects the final node in the pattern to the gravity loading node 3, here 5002 to 3

for i in range(1,numEleBeam1+1):
  if i == 1:
    # ops.element('dispBeamColumn',5000+i,*[5002,200],transfTag, integrationTagBeam)
    ops.element("elasticBeamColumn",5000+i,*[5002,200],Abeam,Econc,Ibeam,transfTag )
  elif i== numEleBeam1:
    # ops.element('dispBeamColumn',5000+i,*[3,5000+i],transfTag, integrationTagBeam)
    ops.element("elasticBeamColumn",5000+i,*[3,5000+i],Abeam,Econc,Ibeam,transfTag)  #first and last elements have different initial and final nodes that don't fit into a pattern
  else:
    # ops.element('dispBeamColumn', 5000+i, *[5000+i+1,5000+i], transfTag, integrationTagBeam) #first beam to the left
    ops.element("elasticBeamColumn", 5000+i, *[5000+i+1,5000+i], Abeam,Econc,Ibeam,transfTag) #first beam to the left outside of the plastic hinge region
# ops.element('dispBeamColumn', 2, *[3,200], transfTag, integrationTagBeam) #beam
# ops.element('dispBeamColumn', 3, *[4,3], transfTag, integrationTagBeam) #beam

for i in range(1,numEleBeam2+1):
  if i == 1:
    # ops.element('dispBeamColumn',5050+i,*[5052,3],transfTag, integrationTagBeam)
    ops.element("elasticBeamColumn",5050+i,*[5052,3],Abeam,Econc,Ibeam,transfTag)
  elif i== numEleBeam2:
    # ops.element('dispBeamColumn',5050+i,*[4,5050+i],transfTag, integrationTagBeam)
    ops.element("elasticBeamColumn",5050+i,*[4,5050+i],Abeam,Econc,Ibeam,transfTag)
  else:
    # ops.element('dispBeamColumn', 5050+i, *[5050+i+1,5050+i], transfTag, integrationTagBeam) #first beam to the left
    ops.element("elasticBeamColumn", 5050+i, *[5050+i+1,5050+i],Abeam,Econc,Ibeam,transfTag) #first beam to the left
# ops.element('dispBeamColumn', 2, *[3,200], transfTag, integrationTagBeam) #beam
# ops.element('dispBeamColumn', 3, *[4,3], transfTag, integrationTagBeam) #beam

# %%
#################### right beam of the plastic hinge region#############
ops.element("dispBeamColumn", 4, *[5,500], transfTag, integrationTagBeamPlasticHinges) #right beam
# ops.element('dispBeamColumn', 4, *[5,500], transfTag, integrationTagBeamPlasticHinges) #right beam
for i in range(1,numEleBeam1+1):
  if i == 1:
    ops.element('dispBeamColumn',6000+i,*[500,6002],transfTag, integrationTagBeam)
  elif i== numEleBeam1:
    ops.element('dispBeamColumn',6000+i,*[6000+i,6],transfTag, integrationTagBeam)
  else:
    ops.element('dispBeamColumn', 6000+i, *[6000+i,6000+i+1], transfTag, integrationTagBeam) #first beam to the right till the gravity load point
# ops.element('dispBeamColumn', 2, *[3,200], transfTag, integrationTagBeam) #beam
# ops.element('dispBeamColumn', 3, *[4,3], transfTag, integrationTagBeam) #beam

for i in range(1,numEleBeam2+1):
  if i == 1:
    ops.element('dispBeamColumn',6050+i,*[6,6052],transfTag, integrationTagBeam)
  elif i== numEleBeam2:
    ops.element('dispBeamColumn',6050+i,*[6050+i,7],transfTag, integrationTagBeam)
  else:
    ops.element('dispBeamColumn', 6050+i, *[6050+i,6050+i+1], transfTag, integrationTagBeam) #beam to the right of the gravity load point
# ops.element('dispBeamColumn', 2, *[3,200], transfTag, integrationTagBeam) #beam
# ops.element('dispBeamColumn', 3, *[4,3], transfTag, integrationTagBeam) #beam

# %%
#bottom columns for the beam column joint
# ops.element('dispBeamColumn', 4, *[5,500], transfTag, integrationTagBeamPlasticHinges) #right beam
# ops.element('dispBeamColumn', 5, *[500,6], transfTag, integrationTagBeam) #beam
# ops.element('dispBeamColumn', 6, *[6,7], transfTag, integrationTagBeam) #beam
ops.element('dispBeamColumn', 7, *[10,1000], transfTag, integrationTagColumnPlasticHinges)  #bottom column
for i in range(1,numEleCol+1):
  if i == 1:
    ops.element('dispBeamColumn',50+i,*[1000,52],transfTag, integrationTagColumn)
  elif i== numEleCol:
    ops.element('dispBeamColumn',50+i,*[50+i,11],transfTag, integrationTagColumn)
  else:
    ops.element('dispBeamColumn', 50+i, *[50+i,50+i+1], transfTag, integrationTagColumn)  #bottom column
# ops.element('dispBeamColumn', 8, *[1000,11], transfTag, integrationTagColumn)  #bottom column

# %%
# top columns for the beam column joint
ops.element('dispBeamColumn', 9, *[8,800], transfTag, integrationTagColumnPlasticHinges)  #top column
for i in range(1,numEleCol+1):
  if i == 1:
    ops.element('dispBeamColumn',500+i,*[800,502],transfTag, integrationTagColumn)
  elif i== numEleCol:
    ops.element('dispBeamColumn',500+i,*[500+i,9],transfTag, integrationTagColumn)
  else:
    ops.element('dispBeamColumn', 500+i, *[500+i,500+i+1], transfTag, integrationTagColumn)  #top column

# element('dispBeamColumn', eleTag, *eleNodes, transfTag, integrationTag, '-cMass', '-mass', mass=0.0)

# %%
#define the fixities for the points
ops.fix(4,0,1,0)
ops.fix(7,0,1,0)
# ops.fix(9,0,1,0)
ops.fix(11,1,1,0)

# %%
# [{eleTag: ops.eleNodes(eleTag)} for eleTag in ops.getEleTags() if eleTag >6000 and eleTag<7000]

# %%
# opsvis.plot_model(node_labels = False, gauss_points = False)
opsvis.plot_model(element_labels = False, gauss_points = False)
fig = plt.gcf()
fig.set_size_inches(12, 8)
plt.show()

# %%
# define the rigid links
ops.rigidLink("-beam",1,8)
ops.rigidLink("-beam",1,5)
ops.rigidLink("-beam",1,10)
ops.rigidLink("-beam",1,2)

# %%
NN = 2
def defineTimeFactorHistory1(peaksArray,scaleFactor,nSteps,nCycles):
    timeFactor = []
    for j,thisPeak in enumerate(peaksArray):
        for i in range(nCycles):
            timeFactor = np.append(timeFactor,np.linspace(0,thisPeak*scaleFactor,nSteps*j**3))
            timeFactor = np.append(timeFactor,np.linspace(thisPeak*scaleFactor,-thisPeak*scaleFactor,nSteps*j**3))
            timeFactor = np.append(timeFactor,np.linspace(-thisPeak*scaleFactor,0,nSteps*j**3))
def defineTimeFactorHistoryMonotonic(peaksArray,scaleFactor,nSteps,nCycles):
    timeFactor = [0]
    for j,thisPeak in enumerate(peaksArray):
        timeFactor = np.append(timeFactor,np.linspace(timeFactor[-1],thisPeak*scaleFactor,nSteps*j**NN,endpoint  = False))
            # timeFactor = np.append(timeFactor,np.linspace(thisPeak*scaleFactor,-thisPeak*scaleFactor,nSteps*j**3))
            # timeFactor = np.append(timeFactor,np.linspace(-thisPeak*scaleFactor,0,nSteps*j**3))
    plt.plot(timeFactor)
    plt.grid()
    plt.xlabel('PseudoTime')
    plt.ylabel('TimeFactor')
    plt.show()
    return timeFactor
# def defineTimeFactorHistoryMonotonic(peaksArray, scaleFactor, nSteps, nCycles, NN=1):
#     timeFactor = [0.0]
#     for j, thisPeak in enumerate(peaksArray, start=1):
#         nPts = int(nSteps * j**NN)
#         start = timeFactor[-1]
#         end = thisPeak * scaleFactor
#         newSegment = np.linspace(start, end, nPts, endpoint=False)
#         timeFactor = np.append(timeFactor, newSegment)

#     plt.plot(timeFactor)
#     plt.grid(True)
#     plt.xlabel('PseudoTime')
#     plt.ylabel('TimeFactor')
#     plt.show()

#     return timeFactor

def defineTimeFactorHistory(peaksArray,scaleFactor,nSteps,nCycles):
    timeFactor = []
    for j,thisPeak in enumerate(peaksArray):
        for i in range(nCycles):
            timeFactor = np.append(timeFactor,np.linspace(0,thisPeak*scaleFactor,nSteps))
            timeFactor = np.append(timeFactor,np.linspace(thisPeak*scaleFactor,-thisPeak*scaleFactor,nSteps))
            timeFactor = np.append(timeFactor,np.linspace(-thisPeak*scaleFactor,0,nSteps))

    plt.plot(timeFactor)
    plt.grid()
    plt.xlabel('PseudoTime')
    plt.ylabel('TimeFactor')
    plt.show()
    return timeFactor


# peaksArray=np.array([11.11,29.6,44.4,59.2,74.0,88.8,103.6,]) #in mm
peaksArray=np.linspace(0,300,30,endpoint=True) #in mm  set this to 0,300,30 for plastic hinge length of D/2
scaleFactor = 1.0
nSteps = 1
nCycles = 1
timeFactorHistory=defineTimeFactorHistoryMonotonic(peaksArray,scaleFactor,nSteps,nCycles)

# %%
ops.timeSeries("Linear",10)
ops.pattern("Plain",10,10)
ops.load(3,0,-55*kN,0)
ops.load(6,0,-55*kN,0)


ops.constraints("Transformation")
ops.numberer("Plain")
ops.system("BandGeneral")
initialTolerance = 1e-8
ops.test("NormDispIncr",initialTolerance,100)
# integrator('DisplacementControl', nodeTag, dof, incr, numIter=1, dUmin=incr, dUmax=incr)
ops.integrator("LoadControl",0.1)
ops.algorithm("Newton")
ops.analysis("Static")
ok = ops.analyze(10)
ops.loadConst('-time', 0.0)
ops.wipeAnalysis()
# ops.setTime(0.0)
opsvis.plot_defo()

ops.timeSeries("Linear",1)  #Displacement control
ops.pattern("Plain",1,1)
ops.load(9,1,0,0)

# recorder('Element', '-file', filename, '-xml', filename, '-binary', filename, '-precision', nSD=6, '-timeSeries', tsTag, '-time', '-dT', deltaT=0.0, '-closeOnWrite', '-ele', *eleTags=[], '-eleRange', startEle, endEle, '-region', regionTag, *args)
# ops.recorder('Element', '-file', f"MomentCurvature_plasticHingeLength:{beamPlasticHingeLength/DBeam}.out", '-timeSeries', 1, '-time', '-ele', [5001,1], "section","force")
# ops.recorder('Element', '-file', f"Moment_plasticHingeLength:{beamPlasticHingeLength/DBeam}.out", '-time', '-ele', 1, "section","Force")
# ops.recorder('Element', '-file', f"Curvature_plasticHingeLength:{beamPlasticHingeLength/DBeam}.out", '-time', '-ele', 1, "section","deformation")


ops.constraints("Transformation")
ops.numberer("Plain")
ops.system("UmfPack")
initialTolerance = 1e-8 #initially 1e-8
ops.test("NormDispIncr",initialTolerance,100)
initialDisplacementIncrement  = timeFactorHistory[1] - timeFactorHistory[0]
# integrator('DisplacementControl', nodeTag, dof, incr, numIter=1, dUmin=incr, dUmax=incr)
ops.integrator("DisplacementControl",9,1,initialDisplacementIncrement,100)  #load to be applied at the tip of the beam free end
ops.algorithm("KrylovNewton")
ops.analysis("Static")
freeEndDisp = [ops.nodeDisp(9,1)]
loadFactor = [ops.getLoadFactor(1)]

ok = ops.analyze(1)
n = 1

freeEndDisp.append(ops.nodeDisp(9,1))
loadFactor.append(ops.getLoadFactor(1))

noOfAttempt = 0
while ok==0 and n<len(timeFactorHistory)-1:
# while ok==0 and n<20:

  displacementIncrement = timeFactorHistory[n+1] - timeFactorHistory[n]
  # print(displacementIncrement)
  ops.integrator("DisplacementControl",9,1,displacementIncrement,100)
  ok = ops.analyze(1)
  modifiedTolerance = initialTolerance*10
  noOfAttempt = 0
  while ok!=0 and noOfAttempt < 8: #initially 4 set to 6
    ops.test("NormDispIncr",modifiedTolerance,100)
    ok = ops.analyze(1)
    modifiedTolerance = modifiedTolerance*10
    noOfAttempt+=1
  if ok!=0:
    break
  ops.test("NormDispIncr",initialTolerance,100)
  freeEndDisp.append(ops.nodeDisp(9,1))
  print(f"The freeEndDisp has been equal to {ops.nodeDisp(9,1)} at the load of {ops.getLoadFactor(1)}.")
  loadFactor.append(ops.getLoadFactor(1))
  n+=1
# Out:
# WARNING: CTestNormDispIncr::test() - failed to converge
# after: 100 iterations  current Norm: 0.00132471 (max: 1e-08, Norm deltaR: 367.24)
# NewtonRaphson::solveCurrentStep() -the ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 8 with domain at load factor 0.9
# OpenSees > analyze failed, returned: -3 error flag
# The freeEndDisp has been equal to -0.07210136424857658 at the load of 9.256451340133327e-16.
# The freeEndDisp has been equal to 5.100312428854872 at the load of 29.72006921830718.
# The freeEndDisp has been equal to 10.27272622195832 at the load of 56.86171640479781.
# The freeEndDisp has been equal to 15.445140015061769 at the load of 69.35746768581127.
# The freeEndDisp has been equal to 15.445140015061769 at the load of 69.35746768581129.
# The freeEndDisp has been equal to 17.16927794609625 at the load of 70.21446560041844.
# The freeEndDisp has been equal to 18.89341587713073 at the load of 70.88600676237587.
# The freeEndDisp has been equal to 20.617553808165216 at the load of 71.05353455905782.
# The freeEndDisp has been equal to 22.3416917391997 at the load of 71.58204060057069.
# The freeEndDisp has been equal to 24.065829670234184 at the load of 72.01538323699756.
# The freeEndDisp has been equal to 25.789967601268664 at the load of 72.42357976732447.
# The freeEndDisp has been equal to 27.514105532303148 at the load of 72.779909048941.
# The freeEndDisp has been equal to 29.23824346333763 at the load of 73.13458167319081.
# The freeEndDisp has been equal to 29.23824346333763 at the load of 73.13458167319041.
# The freeEndDisp has been equal to 29.992553808165216 at the load of 73.29228249324595.
# The freeEndDisp has been equal to 30.746864152992803 at the load of 73.44887153923295.
# The freeEndDisp has been equal to 31.501174497820386 at the load of 73.59102731206589.
# The freeEndDisp has been equal to 32.255484842647974 at the load of 73.74031427098744.
# The freeEndDisp has been equal to 33.009795187475554 at the load of 73.88991646562465.
# The freeEndDisp has been equal to 33.76410553230314 at the load of 74.03860823796282.
# The freeEndDisp has been equal to 34.51841587713073 at the load of 74.18627750402818.
# The freeEndDisp has been equal to 35.272726221958315 at the load of 74.33294289221062.
# The freeEndDisp has been equal to 36.0270365667859 at the load of 74.4785775027828.
# The freeEndDisp has been equal to 36.78134691161349 at the load of 74.62316327925839.
# The freeEndDisp has been equal to 37.53565725644107 at the load of 74.76663444044136.
# The freeEndDisp has been equal to 38.28996760126866 at the load of 74.9077346066389.
# The freeEndDisp has been equal to 39.044277946096244 at the load of 75.04453606481268.
# The freeEndDisp has been equal to 39.79858829092383 at the load of 75.17487002741568.
# The freeEndDisp has been equal to 40.55289863575142 at the load of 75.30427807553531.
# The freeEndDisp has been equal to 40.55289863575142 at the load of 75.30427807553488.
# The freeEndDisp has been equal to 40.9968641529928 at the load of 75.38026358958467.
# The freeEndDisp has been equal to 41.44082967023418 at the load of 75.45165622186197.
# The freeEndDisp has been equal to 41.884795187475554 at the load of 75.50797862049917.
# The freeEndDisp has been equal to 42.328760704716935 at the load of 75.57575503967152.
# The freeEndDisp has been equal to 42.772726221958315 at the load of 75.6432976907801.
# The freeEndDisp has been equal to 43.216691739199696 at the load of 75.7105921897883.
# The freeEndDisp has been equal to 43.66065725644108 at the load of 75.77760864174299.
# The freeEndDisp has been equal to 44.10462277368245 at the load of 75.84435673533659.
# The freeEndDisp has been equal to 44.54858829092383 at the load of 75.90765863660134.
# The freeEndDisp has been equal to 44.99255380816521 at the load of 75.96948464158292.
# The freeEndDisp has been equal to 45.43651932540659 at the load of 76.03109832374929.
# The freeEndDisp has been equal to 45.880484842647974 at the load of 76.09252947902958.
# The freeEndDisp has been equal to 46.32445035988935 at the load of 76.15301297284334.
# The freeEndDisp has been equal to 46.76841587713073 at the load of 76.21314843932308.
# The freeEndDisp has been equal to 47.21238139437211 at the load of 76.27311568229143.
# The freeEndDisp has been equal to 47.65634691161349 at the load of 76.33291253260325.
# The freeEndDisp has been equal to 48.10031242885486 at the load of 76.39253674163272.
# The freeEndDisp has been equal to 48.544277946096244 at the load of 76.45198597639236.
# The freeEndDisp has been equal to 48.988243463337625 at the load of 76.51125781423387.
# The freeEndDisp has been equal to 49.432208980579006 at the load of 76.57034973708559.
# The freeEndDisp has been equal to 49.87617449782039 at the load of 76.62925912517386.
# The freeEndDisp has been equal to 50.32014001506177 at the load of 76.68798325016914.
# The freeEndDisp has been equal to 50.76410553230314 at the load of 76.7465192676893.
# The freeEndDisp has been equal to 51.20807104954452 at the load of 76.8048642090823.
# The freeEndDisp has been equal to 51.20807104954452 at the load of 76.80486420908227.
# The freeEndDisp has been equal to 51.50775974686253 at the load of 76.84696499234164.
# The freeEndDisp has been equal to 51.80744844418054 at the load of 76.88613373326335.
# The freeEndDisp has been equal to 52.10713714149855 at the load of 76.9252120057856.
# The freeEndDisp has been equal to 52.40682583881655 at the load of 76.96419875652485.
# The freeEndDisp has been equal to 52.70651453613456 at the load of 77.00309289770529.
# The freeEndDisp has been equal to 53.00620323345257 at the load of 77.04189330532782.
# The freeEndDisp has been equal to 53.30589193077058 at the load of 77.0805988172054.
# The freeEndDisp has been equal to 53.60558062808858 at the load of 77.1192082308523.
# The freeEndDisp has been equal to 53.90526932540659 at the load of 77.15772030121319.
# The freeEndDisp has been equal to 54.2049580227246 at the load of 77.19613373449403.
# The freeEndDisp has been equal to 54.50464672004261 at the load of 77.23444719569162.
# The freeEndDisp has been equal to 54.80433541736061 at the load of 77.27265929761211.
# The freeEndDisp has been equal to 55.10402411467862 at the load of 77.31076859843698.
# The freeEndDisp has been equal to 55.40371281199663 at the load of 77.34877359941666.
# The freeEndDisp has been equal to 55.70340150931464 at the load of 77.38667274124359.
# The freeEndDisp has been equal to 56.00309020663265 at the load of 77.42446440010899.
# The freeEndDisp has been equal to 56.30277890395065 at the load of 77.46214688322632.
# The freeEndDisp has been equal to 56.60246760126866 at the load of 77.49971842487538.
# The freeEndDisp has been equal to 56.90215629858667 at the load of 77.537177180187.
# The freeEndDisp has been equal to 57.20184499590468 at the load of 77.57452122026467.
# The freeEndDisp has been equal to 57.50153369322268 at the load of 77.6117485258476.
# The freeEndDisp has been equal to 57.801222390540694 at the load of 77.64885698054283.
# The freeEndDisp has been equal to 58.1009110878587 at the load of 77.68584436336626.
# The freeEndDisp has been equal to 58.40059978517671 at the load of 77.7227083405037.
# The freeEndDisp has been equal to 58.70028848249471 at the load of 77.7594464561882.
# The freeEndDisp has been equal to 58.999977179812724 at the load of 77.79605612257421.
# The freeEndDisp has been equal to 59.29966587713073 at the load of 77.832534608469.
# The freeEndDisp has been equal to 59.59935457444874 at the load of 77.86887902675842.
# The freeEndDisp has been equal to 59.89904327176674 at the load of 77.90508632033571.
# The freeEndDisp has been equal to 60.198731969084754 at the load of 77.94115324630934.
# The freeEndDisp has been equal to 60.498420666402765 at the load of 77.97707635822272.
# The freeEndDisp has been equal to 60.79810936372077 at the load of 78.01285198597147.
# The freeEndDisp has been equal to 61.09779806103877 at the load of 78.04847621304103.
# The freeEndDisp has been equal to 61.397486758356784 at the load of 78.08394485061413.
# The freeEndDisp has been equal to 61.697175455674795 at the load of 78.11925340800428.
# The freeEndDisp has been equal to 61.697175455674795 at the load of 78.11925340800403.
# The freeEndDisp has been equal to 61.91441048186918 at the load of 78.14627484267331.
# The freeEndDisp has been equal to 62.13164550806357 at the load of 78.1716806827009.
# The freeEndDisp has been equal to 62.34888053425795 at the load of 78.1969958521907.
# The freeEndDisp has been equal to 62.56611556045234 at the load of 78.22221815807382.
# The freeEndDisp has been equal to 62.783350586646726 at the load of 78.24734527440596.
# The freeEndDisp has been equal to 63.000585612841114 at the load of 78.27237473008593.
# The freeEndDisp has been equal to 63.217820639035494 at the load of 78.29730389506128.
# The freeEndDisp has been equal to 63.43505566522988 at the load of 78.32212996478684.
# The freeEndDisp has been equal to 63.65229069142427 at the load of 78.34684994265828.
# The freeEndDisp has been equal to 63.86952571761866 at the load of 78.37146062008843.
# The freeEndDisp has been equal to 64.08676074381304 at the load of 78.39595855382744.
# The freeEndDisp has been equal to 64.30399577000743 at the load of 78.42034004004681.
# The freeEndDisp has been equal to 64.5212307962018 at the load of 78.44543320051518.
# The freeEndDisp has been equal to 64.7384658223962 at the load of 78.47083421280816.
# The freeEndDisp has been equal to 64.95570084859058 at the load of 78.49614246851783.
# The freeEndDisp has been equal to 65.17293587478497 at the load of 78.52135569802599.
# The freeEndDisp has been equal to 65.39017090097936 at the load of 78.54647149130652.
# The freeEndDisp has been equal to 65.60740592717374 at the load of 78.57148728463541.
# The freeEndDisp has been equal to 65.82464095336813 at the load of 78.59640034562963.
# The freeEndDisp has been equal to 66.04187597956252 at the load of 78.62120775635216.
# The freeEndDisp has been equal to 66.25911100575689 at the load of 78.64590639416804.
# The freeEndDisp has been equal to 66.47634603195128 at the load of 78.67396441235468.
# The freeEndDisp has been equal to 66.69358105814567 at the load of 78.70272021882458.
# The freeEndDisp has been equal to 66.91081608434006 at the load of 78.7314181597948.
# The freeEndDisp has been equal to 67.12805111053444 at the load of 78.76005746949865.
# The freeEndDisp has been equal to 67.34528613672883 at the load of 78.78863734307957.
# The freeEndDisp has been equal to 67.56252116292322 at the load of 78.8171569327963.
# The freeEndDisp has been equal to 67.7797561891176 at the load of 78.84561534384173.
# The freeEndDisp has been equal to 67.99699121531198 at the load of 78.87401162945461.
# The freeEndDisp has been equal to 68.21422624150637 at the load of 78.90234478542334.
# The freeEndDisp has been equal to 68.43146126770075 at the load of 78.93061374382562.
# The freeEndDisp has been equal to 68.64869629389514 at the load of 78.9588173658531.
# The freeEndDisp has been equal to 68.86593132008953 at the load of 78.98695443357684.
# The freeEndDisp has been equal to 69.08316634628392 at the load of 79.01502364047032.
# The freeEndDisp has been equal to 69.3004013724783 at the load of 79.04302358047258.
# The freeEndDisp has been equal to 69.51763639867269 at the load of 79.07095273533443.
# The freeEndDisp has been equal to 69.73487142486708 at the load of 79.09880945994199.
# The freeEndDisp has been equal to 69.95210645106145 at the load of 79.12659196525742.
# The freeEndDisp has been equal to 70.16934147725584 at the load of 79.15429829845182.
# The freeEndDisp has been equal to 70.38657650345023 at the load of 79.18192631973245.
# The freeEndDisp has been equal to 70.60381152964462 at the load of 79.20947367528548.
# The freeEndDisp has been equal to 70.821046555839 at the load of 79.23693776566651.
# The freeEndDisp has been equal to 71.03828158203339 at the load of 79.26431570888154.
# The freeEndDisp has been equal to 71.25551660822778 at the load of 79.29579108022172.
# The freeEndDisp has been equal to 71.47275163442215 at the load of 79.3274308067446.
# The freeEndDisp has been equal to 71.68998666061654 at the load of 79.35900271477969.
# The freeEndDisp has been equal to 71.90722168681093 at the load of 79.3905031238781.
# The freeEndDisp has been equal to 72.12445671300532 at the load of 79.42192781716875.
# The freeEndDisp has been equal to 72.12445671300532 at the load of 79.42192781716875.
# The freeEndDisp has been equal to 72.28948894132408 at the load of 79.4479340548863.
# The freeEndDisp has been equal to 72.45452116964286 at the load of 79.47170294925684.
# The freeEndDisp has been equal to 72.61955339796162 at the load of 79.49542027697167.
# The freeEndDisp has been equal to 72.78458562628039 at the load of 79.51908310858799.
# The freeEndDisp has been equal to 72.94961785459917 at the load of 79.54268820778348.
# The freeEndDisp has been equal to 73.11465008291793 at the load of 79.56623200809362.
# The freeEndDisp has been equal to 73.27968231123671 at the load of 79.58971059241362.
# The freeEndDisp has been equal to 73.44471453955548 at the load of 79.61311967740254.
# The freeEndDisp has been equal to 73.60974676787424 at the load of 79.63645460559768.
# The freeEndDisp has been equal to 73.77477899619302 at the load of 79.65971034879989.
# The freeEndDisp has been equal to 73.93981122451179 at the load of 79.68288152706094.
# The freeEndDisp has been equal to 74.10484345283055 at the load of 79.70596244826693.
# The freeEndDisp has been equal to 74.26987568114933 at the load of 79.728947173661.
# The freeEndDisp has been equal to 74.4349079094681 at the load of 79.7518296143782.
# The freeEndDisp has been equal to 74.59994013778686 at the load of 79.77460366278657.
# The freeEndDisp has been equal to 74.76497236610564 at the load of 79.7972633597243.
# The freeEndDisp has been equal to 74.9300045944244 at the load of 79.8198030942772.
# The freeEndDisp has been equal to 75.09503682274317 at the load of 79.84221782663995.
# The freeEndDisp has been equal to 75.26006905106195 at the load of 79.86450331744223.
# The freeEndDisp has been equal to 75.42510127938071 at the load of 79.8889177367892.
# The freeEndDisp has been equal to 75.59013350769949 at the load of 79.9133294993963.
# The freeEndDisp has been equal to 75.75516573601826 at the load of 79.93761533218587.
# The freeEndDisp has been equal to 75.92019796433702 at the load of 79.96177590068487.
# The freeEndDisp has been equal to 76.0852301926558 at the load of 79.98581281113216.
# The freeEndDisp has been equal to 76.25026242097456 at the load of 80.00972912017953.
# The freeEndDisp has been equal to 76.41529464929333 at the load of 80.03352833823699.
# The freeEndDisp has been equal to 76.58032687761211 at the load of 80.05721458025195.
# The freeEndDisp has been equal to 76.74535910593087 at the load of 80.0807919019903.
# The freeEndDisp has been equal to 76.91039133424964 at the load of 80.10426396533671.
# The freeEndDisp has been equal to 77.07542356256842 at the load of 80.12763382512489.
# The freeEndDisp has been equal to 77.24045579088718 at the load of 80.15089312178813.
# The freeEndDisp has been equal to 77.40548801920595 at the load of 80.17401584631726.
# The freeEndDisp has been equal to 77.57052024752473 at the load of 80.19703533347706.
# The freeEndDisp has been equal to 77.73555247584349 at the load of 80.21994571670616.
# The freeEndDisp has been equal to 77.90058470416227 at the load of 80.24289860004696.
# The freeEndDisp has been equal to 78.06561693248103 at the load of 80.26583639719406.
# The freeEndDisp has been equal to 78.2306491607998 at the load of 80.28861092520809.
# The freeEndDisp has been equal to 78.39568138911858 at the load of 80.31119239094262.
# WARNING: CTestNormDispIncr::test() - failed to converge
# after: 100 iterations  current Norm: 2.18759e-05 (max: 1e-08, Norm deltaR: 10.9464)
# AcceleratedNewton::solveCurrentStep() -The ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 80.3335
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestNormDispIncr::test() - failed to converge
# after: 100 iterations  current Norm: 2.18759e-05 (max: 1e-07, Norm deltaR: 10.9464)
# AcceleratedNewton::solveCurrentStep() -The ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 80.3335
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestNormDispIncr::test() - failed to converge
# after: 100 iterations  current Norm: 0.000120661 (max: 1e-08, Norm deltaR: 5.84769)
# AcceleratedNewton::solveCurrentStep() -The ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 80.6487
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestNormDispIncr::test() - failed to converge
# after: 100 iterations  current Norm: 0.000120661 (max: 1e-07, Norm deltaR: 5.84769)
# AcceleratedNewton::solveCurrentStep() -The ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 80.6487
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestNormDispIncr::test() - failed to converge
# after: 100 iterations  current Norm: 0.000120661 (max: 1e-06, Norm deltaR: 5.84769)
# AcceleratedNewton::solveCurrentStep() -The ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 80.6487
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestNormDispIncr::test() - failed to converge
# after: 100 iterations  current Norm: 0.000120661 (max: 1e-05, Norm deltaR: 5.84769)
# AcceleratedNewton::solveCurrentStep() -The ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 80.6487
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestNormDispIncr::test() - failed to converge
# after: 100 iterations  current Norm: 0.000120661 (max: 0.0001, Norm deltaR: 5.84769)
# AcceleratedNewton::solveCurrentStep() -The ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 80.6487
# OpenSees > analyze failed, returned: -3 error flag
# The freeEndDisp has been equal to 78.56071361743734 at the load of 80.3335409154707.
# The freeEndDisp has been equal to 78.72574584575611 at the load of 80.355600278306.
# The freeEndDisp has been equal to 78.89077807407489 at the load of 80.37742582392302.
# The freeEndDisp has been equal to 79.05581030239365 at the load of 80.39901209469815.
# The freeEndDisp has been equal to 79.22084253071242 at the load of 80.42041255317682.
# The freeEndDisp has been equal to 79.3858747590312 at the load of 80.44168035246771.
# The freeEndDisp has been equal to 79.55090698734996 at the load of 80.46285375042733.
# The freeEndDisp has been equal to 79.71593921566874 at the load of 80.48395570231233.
# The freeEndDisp has been equal to 79.8809714439875 at the load of 80.504998813636.
# The freeEndDisp has been equal to 80.04600367230627 at the load of 80.52598978313146.
# The freeEndDisp has been equal to 80.21103590062505 at the load of 80.54693222220826.
# The freeEndDisp has been equal to 80.37606812894381 at the load of 80.56782816348598.
# The freeEndDisp has been equal to 80.54110035726258 at the load of 80.58867884829046.
# The freeEndDisp has been equal to 80.70613258558136 at the load of 80.60948514382393.
# The freeEndDisp has been equal to 80.87116481390012 at the load of 80.63002941488121.
# The freeEndDisp has been equal to 81.03619704221889 at the load of 80.64813072331313.
# The freeEndDisp has been equal to 81.20122927053767 at the load of 80.6574805851132.
# The freeEndDisp has been equal to 81.36626149885643 at the load of 80.67064965263556.
# The freeEndDisp has been equal to 81.5312937271752 at the load of 80.68377435088775.
# The freeEndDisp has been equal to 81.69632595549398 at the load of 80.69685773220854.
# The freeEndDisp has been equal to 81.86135818381274 at the load of 80.7099021511427.
# The freeEndDisp has been equal to 82.0263904121315 at the load of 80.72290942088564.
# The freeEndDisp has been equal to 82.19142264045028 at the load of 80.73588094491232.
# The freeEndDisp has been equal to 82.35645486876905 at the load of 80.74881780101158.
# The freeEndDisp has been equal to 82.52148709708783 at the load of 80.76172080538893.
# The freeEndDisp has been equal to 82.52148709708783 at the load of 80.76172080538892.
# The freeEndDisp has been equal to 82.65123845282271 at the load of 80.78851737052331.
# The freeEndDisp has been equal to 82.78098980855759 at the load of 80.79868463250324.
# WARNING: CTestNormDispIncr::test() - failed to converge
# after: 100 iterations  current Norm: 0.000136294 (max: 1e-08, Norm deltaR: 71.847)
# AcceleratedNewton::solveCurrentStep() -The ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 80.8088
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestNormDispIncr::test() - failed to converge
# after: 100 iterations  current Norm: 0.000231526 (max: 1e-08, Norm deltaR: 156.364)
# AcceleratedNewton::solveCurrentStep() -The ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 80.8189
# OpenSees > analyze failed, returned: -3 error flag
# The freeEndDisp has been equal to 82.91074116429249 at the load of 80.8088244535308.
# The freeEndDisp has been equal to 83.04049252002737 at the load of 80.81888705287705.
# The freeEndDisp has been equal to 83.17024387576225 at the load of 80.82828388699804.
# The freeEndDisp has been equal to 83.29999523149714 at the load of 80.83768309006712.
# The freeEndDisp has been equal to 83.42974658723202 at the load of 80.84702693258771.
# The freeEndDisp has been equal to 83.5594979429669 at the load of 80.85631313352648.
# The freeEndDisp has been equal to 83.6892492987018 at the load of 80.86553915157317.
# The freeEndDisp has been equal to 83.81900065443668 at the load of 80.87470215198307.
# The freeEndDisp has been equal to 83.94875201017156 at the load of 80.88379896509085.
# The freeEndDisp has been equal to 84.07850336590644 at the load of 80.89282603522297.
# The freeEndDisp has been equal to 84.20825472164132 at the load of 80.90177935720924.
# The freeEndDisp has been equal to 84.3380060773762 at the load of 80.91065439780274.
# The freeEndDisp has been equal to 84.4677574331111 at the load of 80.91944599723702.
# The freeEndDisp has been equal to 84.59750878884599 at the load of 80.92814824471107.
# The freeEndDisp has been equal to 84.72726014458087 at the load of 80.93675431849987.
# The freeEndDisp has been equal to 84.85701150031575 at the load of 80.94525627922694.
# The freeEndDisp has been equal to 84.98676285605063 at the load of 78.3723460244531.
# The freeEndDisp has been equal to 85.11651421178551 at the load of 70.00999560415113.
# The freeEndDisp has been equal to 85.24626556752041 at the load of 69.97210693237552.
# The freeEndDisp has been equal to 85.37601692325529 at the load of 69.90152357670732.
# The freeEndDisp has been equal to 85.50576827899017 at the load of 69.78933075791316.
# The freeEndDisp has been equal to 85.63551963472506 at the load of 69.55655552644711.
# The freeEndDisp has been equal to 85.76527099045994 at the load of 69.30667365401372.
# The freeEndDisp has been equal to 85.89502234619482 at the load of 67.60611979841923.
# The freeEndDisp has been equal to 86.02477370192972 at the load of 67.6325031630918.
# The freeEndDisp has been equal to 86.1545250576646 at the load of 67.60391194363496.
# The freeEndDisp has been equal to 86.28427641339948 at the load of 67.451683907136.
# The freeEndDisp has been equal to 86.41402776913436 at the load of 67.53938105553523.
# The freeEndDisp has been equal to 86.54377912486925 at the load of 67.1524122798537.
# The freeEndDisp has been equal to 86.67353048060413 at the load of 63.937886533070575.
# The freeEndDisp has been equal to 86.80328183633902 at the load of 64.16700680966704.
# The freeEndDisp has been equal to 86.9330331920739 at the load of 64.38904454460595.
# The freeEndDisp has been equal to 87.06278454780879 at the load of 64.60349996767115.
# The freeEndDisp has been equal to 87.19253590354367 at the load of 64.80980832393153.
# The freeEndDisp has been equal to 87.32228725927855 at the load of 65.00732874199181.
# The freeEndDisp has been equal to 87.45203861501345 at the load of 65.19532990351892.
# The freeEndDisp has been equal to 87.58178997074833 at the load of 65.37463000762061.
# The freeEndDisp has been equal to 87.71154132648321 at the load of 65.56599386482948.
# The freeEndDisp has been equal to 87.8412926822181 at the load of 65.74743010365398.
# The freeEndDisp has been equal to 87.97104403795298 at the load of 65.94092010766775.
# The freeEndDisp has been equal to 88.10079539368786 at the load of 66.24165450436867.
# The freeEndDisp has been equal to 88.23054674942276 at the load of 66.53199134403263.
# The freeEndDisp has been equal to 88.36029810515764 at the load of 66.8004780098744.
# The freeEndDisp has been equal to 88.49004946089252 at the load of 67.06657667028207.
# The freeEndDisp has been equal to 88.6198008166274 at the load of 67.33035181997288.
# The freeEndDisp has been equal to 88.74955217236229 at the load of 67.58686212682156.
# The freeEndDisp has been equal to 88.87930352809717 at the load of 67.83772402753259.
# The freeEndDisp has been equal to 89.00905488383206 at the load of 68.08440471579384.
# The freeEndDisp has been equal to 89.13880623956695 at the load of 68.32669544737584.
# The freeEndDisp has been equal to 89.26855759530183 at the load of 68.56436945054465.
# The freeEndDisp has been equal to 89.39830895103671 at the load of 68.79717972365496.
# The freeEndDisp has been equal to 89.5280603067716 at the load of 69.02485644959008.
# The freeEndDisp has been equal to 89.65781166250648 at the load of 69.24710396701849.
# The freeEndDisp has been equal to 89.78756301824137 at the load of 69.46359720522835.
# The freeEndDisp has been equal to 89.91731437397625 at the load of 69.6739774610886.
# The freeEndDisp has been equal to 90.04706572971114 at the load of 69.87784736233019.
# The freeEndDisp has been equal to 90.17681708544602 at the load of 70.07476481613885.
# The freeEndDisp has been equal to 90.3065684411809 at the load of 70.26423568050829.
# The freeEndDisp has been equal to 90.43631979691578 at the load of 70.44570480942932.
# The freeEndDisp has been equal to 90.56607115265068 at the load of 70.61854499878302.
# The freeEndDisp has been equal to 90.69582250838556 at the load of 70.78204317880082.
# The freeEndDisp has been equal to 90.82557386412044 at the load of 70.98661754351983.
# The freeEndDisp has been equal to 90.95532521985533 at the load of 71.22519119540645.
# The freeEndDisp has been equal to 91.08507657559021 at the load of 71.45898257563479.
# The freeEndDisp has been equal to 91.2148279313251 at the load of 71.67936557376649.
# The freeEndDisp has been equal to 91.34457928705999 at the load of 71.88515418307901.
# The freeEndDisp has been equal to 91.47433064279487 at the load of 72.08020912480931.
# The freeEndDisp has been equal to 91.60408199852975 at the load of 72.26760650493954.
# The freeEndDisp has been equal to 91.73383335426463 at the load of 72.44639633047494.
# The freeEndDisp has been equal to 91.86358470999951 at the load of 72.6152745431131.
# The freeEndDisp has been equal to 91.9933360657344 at the load of 72.76742506250194.
# The freeEndDisp has been equal to 92.1230874214693 at the load of 72.9037527804538.
# The freeEndDisp has been equal to 92.25283877720418 at the load of 73.02432179698012.
# The freeEndDisp has been equal to 92.38259013293906 at the load of 73.15069782707646.
# The freeEndDisp has been equal to 92.51234148867394 at the load of 73.28644280205297.
# The freeEndDisp has been equal to 92.64209284440882 at the load of 73.40958718186857.
# The freeEndDisp has been equal to 92.77184420014372 at the load of 73.51756277552096.
# The freeEndDisp has been equal to 92.9015955558786 at the load of 73.61111095219509.
# The freeEndDisp has been equal to 92.9015955558786 at the load of 73.61111095219471.
# The freeEndDisp has been equal to 93.00634134529801 at the load of 73.65806327608036.
# The freeEndDisp has been equal to 93.11108713471744 at the load of 73.66872562672343.
# The freeEndDisp has been equal to 93.21583292413685 at the load of 73.67183865094107.
# The freeEndDisp has been equal to 93.32057871355627 at the load of 73.75425221695045.
# The freeEndDisp has been equal to 93.42532450297568 at the load of 73.88199633151774.
# The freeEndDisp has been equal to 93.53007029239511 at the load of 74.00514333747958.
# The freeEndDisp has been equal to 93.63481608181452 at the load of 74.12135145728864.
# The freeEndDisp has been equal to 93.73956187123395 at the load of 74.22220253405757.
# The freeEndDisp has been equal to 93.84430766065336 at the load of 74.30554545106956.
# The freeEndDisp has been equal to 93.94905345007278 at the load of 74.37049764252255.
# The freeEndDisp has been equal to 94.0537992394922 at the load of 74.4236690074705.
# The freeEndDisp has been equal to 94.15854502891162 at the load of 74.47050631191516.
# The freeEndDisp has been equal to 94.26329081833103 at the load of 74.51324221814836.
# The freeEndDisp has been equal to 94.36803660775045 at the load of 74.552556133362.
# The freeEndDisp has been equal to 94.47278239716987 at the load of 74.58857668907464.
# The freeEndDisp has been equal to 94.57752818658929 at the load of 74.62119924432228.
# The freeEndDisp has been equal to 94.6822739760087 at the load of 74.65018281370584.
# The freeEndDisp has been equal to 94.78701976542813 at the load of 74.67517270664943.
# The freeEndDisp has been equal to 94.89176555484754 at the load of 74.69576320311482.
# The freeEndDisp has been equal to 94.99651134426696 at the load of 74.7117318255173.
# The freeEndDisp has been equal to 95.10125713368637 at the load of 74.72330030526724.
# The freeEndDisp has been equal to 95.2060029231058 at the load of 74.73087255586654.
# The freeEndDisp has been equal to 95.31074871252521 at the load of 74.7346354198638.
# The freeEndDisp has been equal to 95.41549450194464 at the load of 74.73453169200788.
# The freeEndDisp has been equal to 95.52024029136405 at the load of 74.76199983616128.
# The freeEndDisp has been equal to 95.62498608078347 at the load of 74.81226773341032.
# The freeEndDisp has been equal to 95.72973187020288 at the load of 74.86100919668066.
# The freeEndDisp has been equal to 95.8344776596223 at the load of 74.90618419379754.
# The freeEndDisp has been equal to 95.93922344904172 at the load of 74.94798735250589.
# The freeEndDisp has been equal to 96.04396923846113 at the load of 74.98693497980834.
# The freeEndDisp has been equal to 96.14871502788056 at the load of 75.02284225900947.
# The freeEndDisp has been equal to 96.25346081729997 at the load of 75.05550311282707.
# The freeEndDisp has been equal to 96.35820660671939 at the load of 75.08468684169686.
# The freeEndDisp has been equal to 96.4629523961388 at the load of 75.11013386789575.
# The freeEndDisp has been equal to 96.56769818555823 at the load of 75.13051467214305.
# The freeEndDisp has been equal to 96.67244397497764 at the load of 75.1315622744495.
# The freeEndDisp has been equal to 96.77718976439706 at the load of 75.1272863756105.
# The freeEndDisp has been equal to 96.88193555381648 at the load of 75.1171820199397.
# The freeEndDisp has been equal to 96.9866813432359 at the load of 75.10065836741502.
# The freeEndDisp has been equal to 97.09142713265531 at the load of 75.08774978402177.
# The freeEndDisp has been equal to 97.19617292207474 at the load of 75.11612663832442.
# The freeEndDisp has been equal to 97.30091871149415 at the load of 75.22297091695737.
# The freeEndDisp has been equal to 97.40566450091357 at the load of 75.33025017997552.
# The freeEndDisp has been equal to 97.51041029033298 at the load of 75.437059026628.
# The freeEndDisp has been equal to 97.61515607975241 at the load of 75.54313669867949.
# The freeEndDisp has been equal to 97.71990186917182 at the load of 75.63115378414004.
# The freeEndDisp has been equal to 97.82464765859125 at the load of 75.73286409404633.
# The freeEndDisp has been equal to 97.92939344801066 at the load of 75.82909106673728.
# The freeEndDisp has been equal to 98.03413923743008 at the load of 75.91766351664998.
# The freeEndDisp has been equal to 98.1388850268495 at the load of 75.99654213161526.
# The freeEndDisp has been equal to 98.24363081626892 at the load of 76.0644212518417.
# The freeEndDisp has been equal to 98.34837660568833 at the load of 76.12429901640343.
# The freeEndDisp has been equal to 98.45312239510774 at the load of 76.17838214412087.
# The freeEndDisp has been equal to 98.55786818452717 at the load of 76.22859018049502.
# The freeEndDisp has been equal to 98.66261397394658 at the load of 76.2757496216388.
# The freeEndDisp has been equal to 98.767359763366 at the load of 76.31952541724915.
# The freeEndDisp has been equal to 98.87210555278541 at the load of 76.35916415191583.
# The freeEndDisp has been equal to 98.97685134220484 at the load of 76.39398432006925.
# The freeEndDisp has been equal to 99.08159713162425 at the load of 76.42429753344689.
# The freeEndDisp has been equal to 99.18634292104367 at the load of 76.45120606853719.
# The freeEndDisp has been equal to 99.29108871046309 at the load of 76.4756384642678.
# The freeEndDisp has been equal to 99.39583449988251 at the load of 76.4980962855531.
# The freeEndDisp has been equal to 99.50058028930192 at the load of 76.5192486588838.
# The freeEndDisp has been equal to 99.60532607872135 at the load of 76.53899635031411.
# The freeEndDisp has been equal to 99.71007186814076 at the load of 76.55701278328476.
# The freeEndDisp has been equal to 99.81481765756018 at the load of 76.57288058641291.
# The freeEndDisp has been equal to 99.9195634469796 at the load of 76.58625165149141.
# The freeEndDisp has been equal to 100.02430923639902 at the load of 76.59700095092514.
# The freeEndDisp has been equal to 100.12905502581843 at the load of 76.6052937523736.
# The freeEndDisp has been equal to 100.23380081523786 at the load of 76.61115047863838.
# The freeEndDisp has been equal to 100.33854660465727 at the load of 76.6151473000235.
# The freeEndDisp has been equal to 100.44329239407669 at the load of 76.6179678936609.
# The freeEndDisp has been equal to 100.5480381834961 at the load of 76.61998242096203.
# The freeEndDisp has been equal to 100.65278397291553 at the load of 76.62145582547545.
# The freeEndDisp has been equal to 100.75752976233494 at the load of 76.62256731866954.
# The freeEndDisp has been equal to 100.86227555175437 at the load of 76.6234345845603.
# The freeEndDisp has been equal to 100.96702134117378 at the load of 76.62413392606774.
# The freeEndDisp has been equal to 101.07176713059319 at the load of 76.62471469478314.
# The freeEndDisp has been equal to 101.17651292001261 at the load of 76.62520892528754.
# The freeEndDisp has been equal to 101.28125870943204 at the load of 76.625637556197.
# The freeEndDisp has been equal to 101.38600449885145 at the load of 76.62601439125437.
# The freeEndDisp has been equal to 101.49075028827086 at the load of 76.62634861349626.
# The freeEndDisp has been equal to 101.59549607769029 at the load of 76.62664638594475.
# The freeEndDisp has been equal to 101.7002418671097 at the load of 76.62691187751896.
# The freeEndDisp has been equal to 101.80498765652912 at the load of 76.62714792627669.
# The freeEndDisp has been equal to 101.90973344594853 at the load of 76.6273564723795.
# The freeEndDisp has been equal to 102.01447923536796 at the load of 76.62753884362678.
# The freeEndDisp has been equal to 102.11922502478737 at the load of 76.62769594571188.
# The freeEndDisp has been equal to 102.2239708142068 at the load of 76.6278283902918.
# The freeEndDisp has been equal to 102.3287166036262 at the load of 76.62793658205914.
# The freeEndDisp has been equal to 102.43346239304563 at the load of 76.62802077851288.
# The freeEndDisp has been equal to 102.53820818246504 at the load of 76.62808113136894.
# The freeEndDisp has been equal to 102.64295397188447 at the load of 76.62813892655981.
# The freeEndDisp has been equal to 102.74769976130388 at the load of 76.6367955617377.
# The freeEndDisp has been equal to 102.8524455507233 at the load of 76.64863006648818.
# The freeEndDisp has been equal to 102.95719134014271 at the load of 76.66045181224176.
# The freeEndDisp has been equal to 103.06193712956214 at the load of 76.67226076370173.
# The freeEndDisp has been equal to 103.16668291898155 at the load of 76.68405686777996.
# The freeEndDisp has been equal to 103.27142870840098 at the load of 76.69584005732484.
# The freeEndDisp has been equal to 103.27142870840098 at the load of 76.69584005732484.
# The freeEndDisp has been equal to 103.35778881894335 at the load of 76.80371019007961.
# The freeEndDisp has been equal to 103.4441489294857 at the load of 76.81263504396262.
# The freeEndDisp has been equal to 103.53050904002808 at the load of 76.8215511803809.
# The freeEndDisp has been equal to 103.61686915057044 at the load of 76.83045853721096.
# The freeEndDisp has been equal to 103.70322926111281 at the load of 76.83935705125599.
# The freeEndDisp has been equal to 103.78958937165517 at the load of 76.84824665822573.
# The freeEndDisp has been equal to 103.87594948219754 at the load of 76.85712729270833.
# The freeEndDisp has been equal to 103.9623095927399 at the load of 76.86599888814148.
# The freeEndDisp has been equal to 104.04866970328227 at the load of 76.87486137678245.
# The freeEndDisp has been equal to 104.13502981382464 at the load of 76.8837146896772.
# The freeEndDisp has been equal to 104.221389924367 at the load of 76.89255875662816.
# The freeEndDisp has been equal to 104.30775003490938 at the load of 76.90139350615944.
# The freeEndDisp has been equal to 104.39411014545173 at the load of 76.91021886547641.
# The freeEndDisp has been equal to 104.4804702559941 at the load of 76.91903476040503.
# The freeEndDisp has been equal to 104.56683036653646 at the load of 76.9278411152666.
# The freeEndDisp has been equal to 104.65319047707884 at the load of 76.9366378525572.
# The freeEndDisp has been equal to 104.7395505876212 at the load of 76.94542489207483.
# The freeEndDisp has been equal to 104.82591069816357 at the load of 76.95420214859243.
# The freeEndDisp has been equal to 104.91227080870594 at the load of 76.96296952592876.
# The freeEndDisp has been equal to 104.9986309192483 at the load of 76.97172690259494.
# The freeEndDisp has been equal to 105.08499102979067 at the load of 76.98047409878505.
# The freeEndDisp has been equal to 105.17135114033303 at the load of 76.98921080438504.
# The freeEndDisp has been equal to 105.2577112508754 at the load of 76.99793643138365.
# The freeEndDisp has been equal to 105.34407136141776 at the load of 77.0066498368404.
# The freeEndDisp has been equal to 105.43043147196013 at the load of 77.01534888004164.
# The freeEndDisp has been equal to 105.51679158250249 at the load of 77.02402995144733.
# The freeEndDisp has been equal to 105.60315169304486 at the load of 77.03265023529605.
# The freeEndDisp has been equal to 105.68951180358722 at the load of 77.04122634043175.
# The freeEndDisp has been equal to 105.7758719141296 at the load of 77.04976371145902.
# The freeEndDisp has been equal to 105.86223202467197 at the load of 77.05827224103083.
# The freeEndDisp has been equal to 105.94859213521433 at the load of 77.06676160536729.
# The freeEndDisp has been equal to 106.0349522457567 at the load of 77.07523701964544.
# The freeEndDisp has been equal to 106.12131235629906 at the load of 77.08370063919213.
# The freeEndDisp has been equal to 106.20767246684143 at the load of 77.09215324841885.
# The freeEndDisp has been equal to 106.29403257738379 at the load of 77.10154875520769.
# The freeEndDisp has been equal to 106.38039268792616 at the load of 77.11164994473857.
# The freeEndDisp has been equal to 106.46675279846853 at the load of 77.12174588149342.
# The freeEndDisp has been equal to 106.55311290901089 at the load of 77.13183659027895.
# The freeEndDisp has been equal to 106.63947301955326 at the load of 77.14192206701009.
# The freeEndDisp has been equal to 106.72583313009562 at the load of 77.15200229682635.
# The freeEndDisp has been equal to 106.812193240638 at the load of 77.16207725982842.
# The freeEndDisp has been equal to 106.89855335118035 at the load of 77.17214693272493.
# The freeEndDisp has been equal to 106.98491346172273 at the load of 77.18221128899017.
# The freeEndDisp has been equal to 107.07127357226508 at the load of 77.19227029836591.
# The freeEndDisp has been equal to 107.15763368280746 at the load of 77.20232392595946.
# The freeEndDisp has been equal to 107.24399379334982 at the load of 77.21237213098219.
# The freeEndDisp has been equal to 107.33035390389219 at the load of 77.22241486508388.
# The freeEndDisp has been equal to 107.41671401443456 at the load of 77.23245207018473.
# The freeEndDisp has been equal to 107.50307412497692 at the load of 77.2424836756573.
# The freeEndDisp has been equal to 107.58943423551929 at the load of 77.25250959464735.
# The freeEndDisp has been equal to 107.67579434606165 at the load of 77.26252971923253.
# The freeEndDisp has been equal to 107.76215445660402 at the load of 77.27254391398141.
# The freeEndDisp has been equal to 107.84851456714638 at the load of 77.28255200725866.
# The freeEndDisp has been equal to 107.93487467768875 at the load of 77.2925537792725.
# The freeEndDisp has been equal to 108.02123478823111 at the load of 77.30254894526567.
# The freeEndDisp has been equal to 108.10759489877348 at the load of 77.31243208332471.
# The freeEndDisp has been equal to 108.19395500931586 at the load of 77.32207647148708.
# The freeEndDisp has been equal to 108.28031511985822 at the load of 77.33171202902793.
# The freeEndDisp has been equal to 108.36667523040059 at the load of 77.34133779642822.
# The freeEndDisp has been equal to 108.45303534094295 at the load of 77.35095238033979.
# The freeEndDisp has been equal to 108.53939545148532 at the load of 77.36055365245537.
# The freeEndDisp has been equal to 108.62575556202768 at the load of 77.37013811787205.
# The freeEndDisp has been equal to 108.71211567257005 at the load of 77.37969952837202.
# The freeEndDisp has been equal to 108.79847578311241 at the load of 77.38922476095274.
# The freeEndDisp has been equal to 108.88483589365478 at the load of 77.39867674088008.
# The freeEndDisp has been equal to 108.97119600419715 at the load of 77.40769958574525.
# The freeEndDisp has been equal to 109.05755611473951 at the load of 77.41446519743174.
# The freeEndDisp has been equal to 109.14391622528188 at the load of 77.4210395383355.
# The freeEndDisp has been equal to 109.23027633582424 at the load of 77.4273991960841.
# The freeEndDisp has been equal to 109.31663644636662 at the load of 77.43361491275522.
# The freeEndDisp has been equal to 109.40299655690897 at the load of 77.43981017782298.
# The freeEndDisp has been equal to 109.48935666745135 at the load of 77.44599908598224.
# The freeEndDisp has been equal to 109.5757167779937 at the load of 77.45218195145065.
# The freeEndDisp has been equal to 109.66207688853608 at the load of 77.4583584356394.
# The freeEndDisp has been equal to 109.74843699907844 at the load of 77.46452285687073.
# The freeEndDisp has been equal to 109.83479710962081 at the load of 77.47064275889437.
# The freeEndDisp has been equal to 109.92115722016318 at the load of 77.47672038281418.
# The freeEndDisp has been equal to 110.00751733070554 at the load of 77.48278728757343.
# The freeEndDisp has been equal to 110.09387744124791 at the load of 77.48884752754994.
# The freeEndDisp has been equal to 110.18023755179027 at the load of 77.49489926474415.
# The freeEndDisp has been equal to 110.26659766233264 at the load of 77.50093188144959.
# The freeEndDisp has been equal to 110.352957772875 at the load of 77.50690163756255.
# The freeEndDisp has been equal to 110.43931788341737 at the load of 77.51271431144713.
# The freeEndDisp has been equal to 110.52567799395975 at the load of 77.51839807339452.
# The freeEndDisp has been equal to 110.6120381045021 at the load of 77.52405159928848.
# The freeEndDisp has been equal to 110.69839821504448 at the load of 77.52969700382404.
# The freeEndDisp has been equal to 110.78475832558684 at the load of 77.5353366609526.
# The freeEndDisp has been equal to 110.87111843612921 at the load of 77.54097082201002.
# The freeEndDisp has been equal to 110.95747854667157 at the load of 77.5465994959361.
# The freeEndDisp has been equal to 111.04383865721394 at the load of 77.55222265816843.
# The freeEndDisp has been equal to 111.1301987677563 at the load of 77.55784027842401.
# The freeEndDisp has been equal to 111.21655887829867 at the load of 77.56345232505146.
# The freeEndDisp has been equal to 111.30291898884103 at the load of 77.56905876581162.
# The freeEndDisp has been equal to 111.3892790993834 at the load of 77.5746595680312.
# The freeEndDisp has been equal to 111.47563920992577 at the load of 77.58025469863227.
# The freeEndDisp has been equal to 111.56199932046813 at the load of 77.58584412413437.
# The freeEndDisp has been equal to 111.6483594310105 at the load of 77.59142781064986.
# The freeEndDisp has been equal to 111.73471954155286 at the load of 77.5970057238774.
# The freeEndDisp has been equal to 111.82107965209524 at the load of 77.60257782909494.
# The freeEndDisp has been equal to 111.9074397626376 at the load of 77.60814409115198.
# The freeEndDisp has been equal to 111.99379987317997 at the load of 77.61370447446221.
# The freeEndDisp has been equal to 112.08015998372234 at the load of 77.61925894299533.
# The freeEndDisp has been equal to 112.1665200942647 at the load of 77.62480746026915.
# The freeEndDisp has been equal to 112.25288020480707 at the load of 77.63034998934137.
# The freeEndDisp has been equal to 112.33924031534943 at the load of 77.63588649280076.
# The freeEndDisp has been equal to 112.4256004258918 at the load of 77.64141693275896.
# The freeEndDisp has been equal to 112.51196053643416 at the load of 77.64694127084118.
# The freeEndDisp has been equal to 112.59832064697653 at the load of 77.65245946817731.
# The freeEndDisp has been equal to 112.68468075751889 at the load of 77.65797148539258.
# The freeEndDisp has been equal to 112.77104086806126 at the load of 77.66347728259778.
# The freeEndDisp has been equal to 112.85740097860362 at the load of 77.66897681937972.
# The freeEndDisp has been equal to 112.943761089146 at the load of 77.67447005479104.
# The freeEndDisp has been equal to 113.03012119968837 at the load of 77.67995694733982.
# The freeEndDisp has been equal to 113.11648131023072 at the load of 77.6853604428222.
# WARNING: CTestNormDispIncr::test() - failed to converge
# after: 100 iterations  current Norm: 1.35243e-05 (max: 1e-08, Norm deltaR: 2.61859)
# AcceleratedNewton::solveCurrentStep() -The ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 77.6906
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestNormDispIncr::test() - failed to converge
# after: 100 iterations  current Norm: 1.35243e-05 (max: 1e-07, Norm deltaR: 2.61859)
# AcceleratedNewton::solveCurrentStep() -The ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 77.6906
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestNormDispIncr::test() - failed to converge
# after: 100 iterations  current Norm: 1.35243e-05 (max: 1e-06, Norm deltaR: 2.61859)
# AcceleratedNewton::solveCurrentStep() -The ConvergenceTest object failed in test()
# StaticAnalysis::analyze() - the Algorithm failed at step: 0 with domain at load factor 77.6906
# OpenSees > analyze failed, returned: -3 error flag
# WARNING: CTestNormDispIncr::test() - failed to converge
# after: 100 iterations  current Norm: 1.35243e-05 (max: 1e-05, Norm deltaR: 2.61859)
# AcceleratedNewton::solveCurrentStep() -The ConvergenceTest object failed in test()
# ...
# The freeEndDisp has been equal to 297.64937602035315 at the load of 70.32977234305953.
# The freeEndDisp has been equal to 297.6616923588147 at the load of 70.33071537513203.
# The freeEndDisp has been equal to 297.67400869727635 at the load of 70.33165824615733.
# The freeEndDisp has been equal to 297.686325035738 at the load of 70.3326009554732.
# The freeEndDisp has been equal to 297.69864137419955 at the load of 70.33354350241402.
# The freeEndDisp has been equal to 297.7109577126612 at the load of 70.33448588631104.
# The freeEndDisp has been equal to 297.7232740511228 at the load of 70.33542810649212.
# The freeEndDisp has been equal to 297.7355903895844 at the load of 70.3363701622818.
# The freeEndDisp has been equal to 297.747906728046 at the load of 70.33731205300127.
# The freeEndDisp has been equal to 297.76022306650765 at the load of 70.33825377796845.
# The freeEndDisp has been equal to 297.7725394049692 at the load of 70.33919533649784.
# The freeEndDisp has been equal to 297.78485574343085 at the load of 70.34013672790056.
# The freeEndDisp has been equal to 297.7971720818925 at the load of 70.34107795148435.
# The freeEndDisp has been equal to 297.80948842035406 at the load of 70.34201900655356.
# The freeEndDisp has been equal to 297.8218047588157 at the load of 70.34295989240907.
# The freeEndDisp has been equal to 297.8341210972773 at the load of 70.3439006083484.
# The freeEndDisp has been equal to 297.8464374357389 at the load of 70.34484115366554.
# The freeEndDisp has been equal to 297.8587537742005 at the load of 70.34578152765106.
# The freeEndDisp has been equal to 297.87107011266215 at the load of 70.34672172959203.
# The freeEndDisp has been equal to 297.8833864511237 at the load of 70.34766175877205.
# The freeEndDisp has been equal to 297.89570278958536 at the load of 70.34860161447119.
# The freeEndDisp has been equal to 297.908019128047 at the load of 70.34954129596596.
# The freeEndDisp has been equal to 297.9203354665086 at the load of 70.35048080252943.
# The freeEndDisp has been equal to 297.9326518049702 at the load of 70.35142013343102.
# The freeEndDisp has been equal to 297.9449681434318 at the load of 70.35235928793665.
# The freeEndDisp has been equal to 297.95728448189345 at the load of 70.35329826530857.
# The freeEndDisp has been equal to 297.969600820355 at the load of 70.35423706480553.
# The freeEndDisp has been equal to 297.98191715881666 at the load of 70.35517568568264.
# The freeEndDisp has been equal to 297.9942334972783 at the load of 70.3561141271913.
# The freeEndDisp has been equal to 298.00654983573986 at the load of 70.35705238857943.
# The freeEndDisp has been equal to 298.0188661742015 at the load of 70.35799046909112.
# The freeEndDisp has been equal to 298.0311825126631 at the load of 70.35892836796694.
# The freeEndDisp has been equal to 298.0434988511247 at the load of 70.35986608444368.
# The freeEndDisp has been equal to 298.0558151895863 at the load of 70.36080361775451.
# The freeEndDisp has been equal to 298.06813152804796 at the load of 70.36174096712877.
# The freeEndDisp has been equal to 298.08044786650953 at the load of 70.36267813179217.
# The freeEndDisp has been equal to 298.09276420497116 at the load of 70.36361511096669.
# The freeEndDisp has been equal to 298.1050805434328 at the load of 70.3645519038705.
# The freeEndDisp has been equal to 298.1173968818944 at the load of 70.36548850971802.
# The freeEndDisp has been equal to 298.129713220356 at the load of 70.36642492771988.
# The freeEndDisp has been equal to 298.1420295588176 at the load of 70.36736115708297.
# The freeEndDisp has been equal to 298.15434589727926 at the load of 70.36829719701026.
# The freeEndDisp has been equal to 298.16666223574083 at the load of 70.36923304670104.
# The freeEndDisp has been equal to 298.17897857420246 at the load of 70.37016870535061.
# The freeEndDisp has been equal to 298.1912949126641 at the load of 70.37110417215055.
# The freeEndDisp has been equal to 298.20361125112566 at the load of 70.3720394462885.
# The freeEndDisp has been equal to 298.2159275895873 at the load of 70.37297452694823.
# The freeEndDisp has been equal to 298.2282439280489 at the load of 70.37390941330966.
# The freeEndDisp has been equal to 298.2405602665105 at the load of 70.37484410454876.
# The freeEndDisp has been equal to 298.25287660497213 at the load of 70.37577859983759.
# The freeEndDisp has been equal to 298.26519294343376 at the load of 70.37671289834432.
# The freeEndDisp has been equal to 298.27750928189533 at the load of 70.37764699923315.
# The freeEndDisp has been equal to 298.28982562035696 at the load of 70.37858090166432.
# The freeEndDisp has been equal to 298.3021419588186 at the load of 70.3795146047941.
# The freeEndDisp has been equal to 298.31445829728017 at the load of 70.38044810777475.
# The freeEndDisp has been equal to 298.3267746357418 at the load of 70.38138140975461.
# The freeEndDisp has been equal to 298.33909097420343 at the load of 70.38231450987799.
# The freeEndDisp has been equal to 298.351407312665 at the load of 70.38324740728513.
# The freeEndDisp has been equal to 298.36372365112663 at the load of 70.3841801011123.
# The freeEndDisp has been equal to 298.37603998958826 at the load of 70.38511259049169.
# The freeEndDisp has been equal to 298.3883563280499 at the load of 70.38604487455146.
# The freeEndDisp has been equal to 298.40067266651147 at the load of 70.38697695241568.
# The freeEndDisp has been equal to 298.4129890049731 at the load of 70.3879088232044.
# The freeEndDisp has been equal to 298.42530534343473 at the load of 70.38884048603347.
# The freeEndDisp has been equal to 298.4376216818963 at the load of 70.3897719400148.
# The freeEndDisp has been equal to 298.44993802035793 at the load of 70.39070318425601.
# The freeEndDisp has been equal to 298.46225435881956 at the load of 70.39163421786077.
# The freeEndDisp has been equal to 298.47457069728114 at the load of 70.39256503992846.
# The freeEndDisp has been equal to 298.48688703574277 at the load of 70.39349564955445.
# The freeEndDisp has been equal to 298.4992033742044 at the load of 70.39442604582985.
# The freeEndDisp has been equal to 298.511519712666 at the load of 70.39535622784172.
# The freeEndDisp has been equal to 298.5238360511276 at the load of 70.39628619467283.
# The freeEndDisp has been equal to 298.53615238958923 at the load of 70.39721594540183.
# The freeEndDisp has been equal to 298.5484687280508 at the load of 70.39814547910316.
# The freeEndDisp has been equal to 298.56078506651244 at the load of 70.39907479484708.
# The freeEndDisp has been equal to 298.57310140497407 at the load of 70.40000389169961.
# The freeEndDisp has been equal to 298.58541774343564 at the load of 70.40093276872257.
# The freeEndDisp has been equal to 298.5977340818973 at the load of 70.40186142497355.
# The freeEndDisp has been equal to 298.6100504203589 at the load of 70.40278985950586.
# The freeEndDisp has been equal to 298.62236675882053 at the load of 70.40371807136863.
# The freeEndDisp has been equal to 298.6346830972821 at the load of 70.40464605960666.
# The freeEndDisp has been equal to 298.64699943574374 at the load of 70.40557382326057.
# The freeEndDisp has been equal to 298.65931577420537 at the load of 70.40650136136667.
# The freeEndDisp has been equal to 298.67163211266694 at the load of 70.40742867295695.
# The freeEndDisp has been equal to 298.6839484511286 at the load of 70.40835575705921.
# The freeEndDisp has been equal to 298.6962647895902 at the load of 70.40928261269691.
# The freeEndDisp has been equal to 298.7085811280518 at the load of 70.41020923888915.
# The freeEndDisp has been equal to 298.7208974665134 at the load of 70.41113563465083.
# The freeEndDisp has been equal to 298.73321380497504 at the load of 70.41206179899247.
# The freeEndDisp has been equal to 298.7455301434366 at the load of 70.41298773092032.
# The freeEndDisp has been equal to 298.75784648189824 at the load of 70.41391342943629.
# The freeEndDisp has been equal to 298.7701628203599 at the load of 70.41483889353793.
# The freeEndDisp has been equal to 298.78247915882145 at the load of 70.41576412221855.
# The freeEndDisp has been equal to 298.7947954972831 at the load of 70.41668911446702.
# The freeEndDisp has been equal to 298.8071118357447 at the load of 70.41761386926792.
# The freeEndDisp has been equal to 298.8194281742063 at the load of 70.41853838560148.
# The freeEndDisp has been equal to 298.8317445126679 at the load of 70.4194626624436.
# The freeEndDisp has been equal to 298.84406085112954 at the load of 70.4203866987658.
# The freeEndDisp has been equal to 298.85637718959117 at the load of 70.42131049353527.
# The freeEndDisp has been equal to 298.86869352805275 at the load of 70.42223404571484.
# The freeEndDisp has been equal to 298.8810098665144 at the load of 70.42315735426297.
# The freeEndDisp has been equal to 298.893326204976 at the load of 70.42408041813378.
# The freeEndDisp has been equal to 298.9056425434376 at the load of 70.42500323627704.
# The freeEndDisp has been equal to 298.9179588818992 at the load of 70.4259258076381.
# The freeEndDisp has been equal to 298.93027522036084 at the load of 70.426848131158.
# The freeEndDisp has been equal to 298.9425915588224 at the load of 70.42777020577343.
# The freeEndDisp has been equal to 298.95490789728404 at the load of 70.42869203041668.
# The freeEndDisp has been equal to 298.9672242357457 at the load of 70.42961360401569.
# The freeEndDisp has been equal to 298.97954057420725 at the load of 70.43053492549406.
# The freeEndDisp has been equal to 298.9918569126689 at the load of 70.43145599377102.
# The freeEndDisp has been equal to 299.0041732511305 at the load of 70.4323768077614.
# The freeEndDisp has been equal to 299.0164895895921 at the load of 70.43329736637581.
# The freeEndDisp has been equal to 299.0288059280537 at the load of 70.43421766852033.
# The freeEndDisp has been equal to 299.04112226651534 at the load of 70.43513771309682.
# The freeEndDisp has been equal to 299.0534386049769 at the load of 70.4360574990028.
# The freeEndDisp has been equal to 299.06575494343855 at the load of 70.43697702513136.
# The freeEndDisp has been equal to 299.0780712819002 at the load of 70.43789629037134.
# The freeEndDisp has been equal to 299.0903876203618 at the load of 70.43881529360722.
# The freeEndDisp has been equal to 299.1027039588234 at the load of 70.43973403371918.
# The freeEndDisp has been equal to 299.115020297285 at the load of 70.44065250958306.
# The freeEndDisp has been equal to 299.12733663574664 at the load of 70.44157072007037.
# The freeEndDisp has been equal to 299.1396529742082 at the load of 70.44248866404841.
# The freeEndDisp has been equal to 299.15196931266985 at the load of 70.44340634038012.
# The freeEndDisp has been equal to 299.1642856511315 at the load of 70.44432374792416.
# The freeEndDisp has been equal to 299.17660198959305 at the load of 70.44524088553493.
# The freeEndDisp has been equal to 299.1889183280547 at the load of 70.44615775206256.
# The freeEndDisp has been equal to 299.2012346665163 at the load of 70.44707434635298.
# The freeEndDisp has been equal to 299.2135510049779 at the load of 70.44799066724775.
# The freeEndDisp has been equal to 299.2258673434395 at the load of 70.44890671358435.
# The freeEndDisp has been equal to 299.23818368190115 at the load of 70.44982248419595.
# The freeEndDisp has been equal to 299.2505000203627 at the load of 70.45073797791152.
# The freeEndDisp has been equal to 299.26281635882435 at the load of 70.45165319355594.
# The freeEndDisp has been equal to 299.275132697286 at the load of 70.45256812994978.
# The freeEndDisp has been equal to 299.28744903574756 at the load of 70.45348278590953.
# The freeEndDisp has been equal to 299.2997653742092 at the load of 70.45439716024751.
# The freeEndDisp has been equal to 299.3120817126708 at the load of 70.45531125177193.
# The freeEndDisp has been equal to 299.3243980511324 at the load of 70.45622505928687.
# The freeEndDisp has been equal to 299.336714389594 at the load of 70.45713858159233.
# The freeEndDisp has been equal to 299.34903072805565 at the load of 70.45805181748425.
# The freeEndDisp has been equal to 299.3613470665173 at the load of 70.45896476575447.
# The freeEndDisp has been equal to 299.37366340497886 at the load of 70.45987742519087.
# The freeEndDisp has been equal to 299.3859797434405 at the load of 70.46078979457724.
# The freeEndDisp has been equal to 299.3982960819021 at the load of 70.46170187269342.
# The freeEndDisp has been equal to 299.4106124203637 at the load of 70.46261365831528.
# The freeEndDisp has been equal to 299.4229287588253 at the load of 70.46352515021478.
# The freeEndDisp has been equal to 299.43524509728695 at the load of 70.46443634715989.
# The freeEndDisp has been equal to 299.4475614357485 at the load of 70.46534724791469.
# The freeEndDisp has been equal to 299.45987777421016 at the load of 70.46625785123949.
# The freeEndDisp has been equal to 299.4721941126718 at the load of 70.46716815589065.
# The freeEndDisp has been equal to 299.48451045113336 at the load of 70.46807816062073.
# The freeEndDisp has been equal to 299.496826789595 at the load of 70.46898786417857.
# The freeEndDisp has been equal to 299.5091431280566 at the load of 70.4698972653092.
# The freeEndDisp has been equal to 299.5214594665182 at the load of 70.47080636275392.
# The freeEndDisp has been equal to 299.5337758049798 at the load of 70.47171515525037.
# The freeEndDisp has been equal to 299.54609214344146 at the load of 70.4726236415325.
# The freeEndDisp has been equal to 299.5584084819031 at the load of 70.47353182033066.
# The freeEndDisp has been equal to 299.57072482036466 at the load of 70.47443969037154.
# The freeEndDisp has been equal to 299.5830411588263 at the load of 70.47534725037835.
# The freeEndDisp has been equal to 299.5953574972879 at the load of 70.47625449907069.
# The freeEndDisp has been equal to 299.6076738357495 at the load of 70.47716143516482.
# The freeEndDisp has been equal to 299.6199901742111 at the load of 70.47806805737336.
# The freeEndDisp has been equal to 299.63230651267276 at the load of 70.47897436440564.
# The freeEndDisp has been equal to 299.64462285113433 at the load of 70.47988035496763.
# The freeEndDisp has been equal to 299.65693918959596 at the load of 70.48078602776192.
# The freeEndDisp has been equal to 299.6692555280576 at the load of 70.4816913814878.
# The freeEndDisp has been equal to 299.68157186651916 at the load of 70.48259641484138.
# The freeEndDisp has been equal to 299.6938882049808 at the load of 70.48350112651555.
# The freeEndDisp has been equal to 299.7062045434424 at the load of 70.48440551519998.
# The freeEndDisp has been equal to 299.718520881904 at the load of 70.48530957958135.
# The freeEndDisp has been equal to 299.73083722036563 at the load of 70.4862133183432.
# The freeEndDisp has been equal to 299.74315355882726 at the load of 70.48711673016608.
# The freeEndDisp has been equal to 299.75546989728883 at the load of 70.48801981372756.
# The freeEndDisp has been equal to 299.76778623575046 at the load of 70.48892256770236.
# The freeEndDisp has been equal to 299.7801025742121 at the load of 70.48982499076233.
# The freeEndDisp has been equal to 299.79241891267367 at the load of 70.49072708157644.
# The freeEndDisp has been equal to 299.8047352511353 at the load of 70.491628838811.
# The freeEndDisp has been equal to 299.81705158959693 at the load of 70.49253026112957.
# The freeEndDisp has been equal to 299.82936792805856 at the load of 70.49343134719314.
# The freeEndDisp has been equal to 299.84168426652013 at the load of 70.49433209566006.
# The freeEndDisp has been equal to 299.85400060498176 at the load of 70.4952325051862.
# The freeEndDisp has been equal to 299.8663169434434 at the load of 70.49613257442496.
# The freeEndDisp has been equal to 299.87863328190497 at the load of 70.49703230202739.
# The freeEndDisp has been equal to 299.8909496203666 at the load of 70.4979316866421.
# The freeEndDisp has been equal to 299.90326595882823 at the load of 70.49883072691559.
# The freeEndDisp has been equal to 299.9155822972898 at the load of 70.499729421492.

# %%
enveloperight = np.loadtxt(f"envelopeRightPark.txt")
plt.plot(enveloperight[:,1],enveloperight[:,0],'black', marker = "o",markersize = 7, linewidth = 3,ls = "--", label = "Backbone Curve")
# plt.plot(leftEnvelope[1,:],leftEnvelope[0,:],'black', marker = 'o',markersize = 7,linewidth = 3,ls = "--",)
loadFactor = np.array(loadFactor)
# loadFactor = loadFactor - loadFactor[0]
freeEndDisp = np.array(freeEndDisp)
# freeEndDisp = freeEndDisp - freeEndDisp[0]
plt.plot(freeEndDisp,loadFactor,label = "From Opensees")
plt.ylabel("Load (kN)")
plt.xlabel("Displacement at the free end (mm)")
plt.grid()
plt.legend(loc = "lower right")
# plt.title("Park BC Joint")
# from google.colab import files
plt.title(f"Park BC Joint PlasticHingeLength: {beamPlasticHingeLength/DBeam:.2f} of Depth")
plt.savefig(f"Park BC Joint PlasticHingeLength: {beamPlasticHingeLength/DBeam:.2f} of Depth.png")

# 3. Download the file
# files.download(f"Park BC Joint PlasticHingeLength: {beamPlasticHingeLength/DBeam:.2f} of Depth.png")
plt.show()

# %%
maxDisp,maxLoad = freeEndDisp[np.where(loadFactor==np.max(loadFactor))[0][0]], np.max(loadFactor)
maxDisp, maxLoad #these are the values to be returned by the program #key
# Out:
# (np.float64(84.85701150031575), np.float64(80.94525627922694))

# %%
np.where(loadFactor==np.max(loadFactor))[0][0]
# Out:
# np.int64(223)

# %%
opsvis.plot_defo()
# print(loadFactor[0])
timeFactorHistory[-1]
# Out:
# np.float64(299.98768366153837)

# %%
plt.plot(freeEndDisp,loadFactor)
plt.grid()

# %%
data = ops.eleResponse(1,"section",1,"fiberData")
y = data[0:len(data):5]
z = data[1:len(data):5]
A = data[2:len(data):5]
sig = data[3:len(data):5]
strain = data[4:len(data):5]

# %%
plt.scatter(y,np.array(sig)*1000)
plt.show()
plt.scatter(y,np.array(strain))
